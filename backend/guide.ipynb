# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

SYSTEM_PROMPT = "You are a helpful assistant."

response = client.chat.completions.create(
    model="gpt-5",
    messages=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": "Er NMBU en god skole?"}
    ]
)

answer = response.choices[0].message.content
print(answer.upper())
# Out:
# KORT SVAR: JA – SPESIELT HVIS DU ER INTERESSERT I BÆREKRAFT, MILJØ- OG BIOVITENSKAP, VETERINÆRMEDISIN, LANDBRUK, SKOG, AKVAKULTUR ELLER LANDSKAPSARKITEKTUR.
#
# FORDELER:
# - STERKE FAGMILJØER OG FORSKNING INNEN MILJØ, BIOVITENSKAP OG VETERINÆRFAG.
# - TVERRFAGLIG PROFIL MED TYDELIG FOKUS PÅ BÆREKRAFT.
# - GODT LÆRINGSMILJØ MED RELATIVT SMÅ KLASSER OG TILGJENGELIGE FORELESERE.
# - MODERNE CAMPUS I ÅS (INKL. NYE VETERINÆRFASILITETER), 20–30 MIN MED TOG FRA OSLO.
# - AKTIVT STUDENTMILJØ (LINJEFORENINGER, UKA I ÅS, SAMFUNNET).
#
# TING Å VURDERE:
# - SMALERE FAGTILBUD ENN DE STØRSTE UNIVERSITETENE; MINDRE RELEVANT HVIS DU VIL INN I KLASSISKE HUMANIORAFAG, JUSS ELLER MEDISIN (UTENOM VETERINÆR).
# - ÅS ER EN MINDRE CAMPUSBY; SUPERT FOR NOEN, ROLIG FOR ANDRE.
# - GENERELLE UNIVERSITETSRANGERINGER ER MIDT PÅ TRE, MEN NMBU GJØR DET STERKT I SINE NISJEFAG.
#
# HVA VURDERER DU Å STUDERE (FAGOMRÅDE, BACHELOR/MASTER)? DA KAN JEG GI EN MER TREFFSIKKER VURDERING.

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from supabase import create_client

load_dotenv()

openai_client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
supabase = create_client(
    os.getenv("SUPABASE_URL"),
    os.getenv("SUPABASE_KEY")
)

query = "Hvordan søker permisjon?"

SYSTEM_PROMPT = "Du er en profesjonell studieveileder. Du skal utelukkende basere svarene dine på informasjonen som er hentet fra databasen. Svarene skal være sammenhengende, velstrukturerte og gjennomtenkte, med tydelig faglig presisjon. Unngå spekulasjon og antagelser." \
"Dersom databasen ikke gir tilstrekkelig grunnlag for å besvare spørsmålet, skal du eksplisitt opplyse om dette. Språket skal være formelt, klart og veiledende, og tilpasset studenter i høyere utdanning."


embedding = openai_client.embeddings.create(
    model="text-embedding-3-small",
    input=query
).data[0].embedding

result = supabase.rpc(
    "match_embeddings",
    {
        "query_embedding": embedding,
        "match_count": 5
    }
).execute()

context = "\n".join(row["text"] for row in result.data)

response = openai_client.chat.completions.create(
    model="gpt-5-mini",
    messages=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": f"Context:\n{context}\n\nQuestion:\n{query}"}
    ]
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Kort svar:
# Du søker permisjon ved å fylle ut og sende søknadsskjemaet for studiepermisjon som ligger på NMBUs nettsider (det finnes skjema på bokmål og nynorsk). Kontakt studieveileder ved ditt fakultet dersom du har spørsmål.
#
# Stegvis veiledning (basert på informasjon i databasen):
# 1. Avklar type permisjon og om du er kvalifisert
#    - Ubegrunnet permisjon: inntil 2 semestre sammenhengende, forutsetter at du har oppnådd minst 15 studiepoeng i studieprogrammet. Enkelte studieprogram (f.eks. veterinærmedisin, bachelor dyrepleie, PPU, European Master in Animal Breeding and Genetics) kan ikke søke ubegrunnet permisjon. Merk også at ubegrunnet permisjon kun kan innvilges én gang i løpet av studietiden ved NMBU.
#    - Begrunnet permisjon: søkes ved sykdom, fødsel, omsorg for barn, førstegangstjeneste, verv o.l. og må dokumenteres (f.eks. legeerklæring, fødselsattest, innkalling til førstegangstjeneste, dokumentasjon for verv eller andre forhold).
#
# 2. Samle nødvendig dokumentasjon
#    - For begrunnet permisjon må du legge ved aktuell dokumentasjon som angitt (legeerklæring, termin-/fødselsattest, dokumentasjon for verv, osv.).
#    - Hvis du har inngått kontrakt om bachelor- eller mastergradsoppgave: dette påvirker permisjonsmulighetene — permisjon etter at gradsoppgavekontrakt er inngått kan være begrenset, og kontrakten må revideres både før permisjonsperioden og ved permisjonens slutt.
#
# 3. Finn og fyll ut søknadsskjemaet
#    - Benytt skjemaet «Søknad om studiepermisjon» (bokmål eller nynorsk) som ligger på NMBUs nettsider under «Søke om studiepermisjon» / skjemaer for studenter.
#
# 4. Send inn søknaden og følg opp
#    - Kontakt studieveileder ved ditt fakultet hvis du har spørsmål om utfylling eller om du er usikker på regler/konsekvenser.
#    - Dersom du får innvilget permisjon: du kan fortsatt være vurderingsmeldt og semesterregistrert for emner og dermed melde deg til vurdering under permisjonstiden, men du har ikke krav på å følge undervisning eller på studentarbeidsplass ved NMBU i permisjonstiden.
#
# Opplysninger databasen ikke gir (du må kontakte studieveileder eller administrasjon for dette):
# - Nøyaktig fremgangsmåte for innsending av det utfylte skjemaet (hvor skjemaet skal sendes/leveres) og eventuelle frister/turnustid for behandling av søknader er ikke spesifisert i den tilgjengelige teksten. Ta kontakt med studieveileder ved fakultetet ditt eller fagadministrasjonen for praktisk informasjon om innsending og behandlingstid.

# %%
from openai import OpenAI
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

response = client.responses.create(
    model="gpt-5",
    tools=[{"type": "web_search"}],
    input="What was a positive news story from today?"
)

print(response.output_text)
# Out:
# Today, Thursday, January 8, 2026: The Smithsonian’s National Zoo shared that two sloth bear cubs born in December are healthy and thriving—the first sloth bear births there in over a decade, a boost for a vulnerable species with only about 42 individuals in AZA zoos. Public viewing is expected this spring. ([si.edu](https://www.si.edu/newsdesk/releases/smithsonians-national-zoo-and-conservation-biology-institute-welcomes-two-sloth?utm_source=openai))
#
# Want more upbeat headlines from today (tech, health, environment)?

# %% [markdown]
# # Dette er en overskrift
#
# ### Dette er en mindre overskrift
#
# **Dette er fet skrift**
#
# - 1
# - 2
# - 3
#
# `NOTE: ` Dette er et notat
#
# $$
#  x_2 = 2 * 3
# $$
